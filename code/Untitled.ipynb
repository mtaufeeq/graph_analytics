# %%
import itertools
import copy
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Grab edge list data hosted on Gist
edgelist = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/e570c38bcc72a8d102422f2af836513b/raw/89c76b2563dbc0e88384719a35cba0dfc04cd522/edgelist_sleeping_giant.csv')

# %%
edgelist
# Out:
#             node1  node2 trail  distance        color  estimate
# 0    rs_end_north   v_rs    rs      0.30          red         0
# 1            v_rs   b_rs    rs      0.21          red         0
# 2            b_rs   g_rs    rs      0.11          red         0
# 3            g_rs   w_rs    rs      0.18          red         0
# 4            w_rs   o_rs    rs      0.21          red         0
# ..            ...    ...   ...       ...          ...       ...
# 118          v_bv   b_bv    bv      0.08       purple         0
# 119         g_gy2  w_gy2   gy2      0.05  yellowgreen         0
# 120         w_gy2  b_gy2   gy2      0.03  yellowgreen         1
# 121         b_gy2  o_gy2   gy2      0.07  yellowgreen         0
# 122         o_gy2  y_gy2   gy2      0.12  yellowgreen         0
#
# [123 rows x 6 columns]

# %%
# Preview edgelist
edgelist.head(10)
# Out:
#           node1         node2 trail  distance color  estimate
# 0  rs_end_north          v_rs    rs      0.30   red         0
# 1          v_rs          b_rs    rs      0.21   red         0
# 2          b_rs          g_rs    rs      0.11   red         0
# 3          g_rs          w_rs    rs      0.18   red         0
# 4          w_rs          o_rs    rs      0.21   red         0
# 5          o_rs          y_rs    rs      0.12   red         0
# 6          y_rs  rs_end_south    rs      0.39   red         0
# 7  rc_end_north          v_rc    rc      0.70   red         0
# 8          v_rc          b_rc    rc      0.04   red         0
# 9          b_rc          g_rc    rc      0.15   red         0

# %%
# Grab node list data hosted on Gist
nodelist = pd.read_csv('https://gist.githubusercontent.com/brooksandrew/f989e10af17fb4c85b11409fea47895b/raw/a3a8da0fa5b094f1ca9d82e1642b384889ae16e8/nodelist_sleeping_giant.csv')

# %%
nodelist
# Out:
#             id     X     Y
# 0         b_bv  1486   732
# 1         b_bw   716  1357
# 2   b_end_east  3164  1111
# 3   b_end_west   141  1938
# 4          b_g  1725   771
# ..         ...   ...   ...
# 72       y_gy2  1939  1182
# 73        y_rc  1429  1491
# 74        y_rh   717  1852
# 75        y_rs  1805  1246
# 76        y_rt   977  1666
#
# [77 rows x 3 columns]

# %%
# Create empty graph
g = nx.Graph()

# %%
g

# %%
# Add edges and edge attributes
for i, elrow in edgelist.iterrows():
    print(elrow[2:], elrow[2:].to_dict())
    g.add_edge(elrow[0], elrow[1], attr_dict=elrow[2:].to_dict())
# Out:
# trail        rs
# distance    0.3
# color       red
# estimate      0
# Name: 0, dtype: object {'trail': 'rs', 'distance': 0.3, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.21
# color        red
# estimate       0
# Name: 1, dtype: object {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.11
# color        red
# estimate       0
# Name: 2, dtype: object {'trail': 'rs', 'distance': 0.11, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.18
# color        red
# estimate       0
# Name: 3, dtype: object {'trail': 'rs', 'distance': 0.18, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.21
# color        red
# estimate       0
# Name: 4, dtype: object {'trail': 'rs', 'distance': 0.21, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.12
# color        red
# estimate       0
# Name: 5, dtype: object {'trail': 'rs', 'distance': 0.12, 'color': 'red', 'estimate': 0}
# trail         rs
# distance    0.39
# color        red
# estimate       0
# Name: 6, dtype: object {'trail': 'rs', 'distance': 0.39, 'color': 'red', 'estimate': 0}
# trail        rc
# distance    0.7
# color       red
# estimate      0
# Name: 7, dtype: object {'trail': 'rc', 'distance': 0.7, 'color': 'red', 'estimate': 0}
# trail         rc
# distance    0.04
# color        red
# estimate       0
# Name: 8, dtype: object {'trail': 'rc', 'distance': 0.04, 'color': 'red', 'estimate': 0}
# trail         rc
# distance    0.15
# color        red
# estimate       0
# Name: 9, dtype: object {'trail': 'rc', 'distance': 0.15, 'color': 'red', 'estimate': 0}
# trail         rc
# distance    0.13
# color        red
# estimate       0
# Name: 10, dtype: object {'trail': 'rc', 'distance': 0.13, 'color': 'red', 'estimate': 0}
# trail         rc
# distance    0.23
# color        red
# estimate       1
# Name: 11, dtype: object {'trail': 'rc', 'distance': 0.23, 'color': 'red', 'estimate': 1}
# trail         rc
# distance    0.14
# color        red
# estimate       0
# Name: 12, dtype: object {'trail': 'rc', 'distance': 0.14, 'color': 'red', 'estimate': 0}
# trail         rc
# distance    0.36
# color        red
# estimate       0
# Name: 13, dtype: object {'trail': 'rc', 'distance': 0.36, 'color': 'red', 'estimate': 0}
# trail        rt
# distance    0.3
# color       red
# estimate      0
# Name: 14, dtype: object {'trail': 'rt', 'distance': 0.3, 'color': 'red', 'estimate': 0}
# trail         rt
# distance    0.16
# color        red
# estimate       0
# Name: 15, dtype: object {'trail': 'rt', 'distance': 0.16, 'color': 'red', 'estimate': 0}
# trail         rt
# distance    0.04
# color        red
# estimate       1
# Name: 16, dtype: object {'trail': 'rt', 'distance': 0.04, 'color': 'red', 'estimate': 1}
# trail         rt
# distance    0.09
# color        red
# estimate       0
# Name: 17, dtype: object {'trail': 'rt', 'distance': 0.09, 'color': 'red', 'estimate': 0}
# trail         rt
# distance    0.05
# color        red
# estimate       1
# Name: 18, dtype: object {'trail': 'rt', 'distance': 0.05, 'color': 'red', 'estimate': 1}
# trail         rt
# distance    0.06
# color        red
# estimate       0
# Name: 19, dtype: object {'trail': 'rt', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# trail         rt
# distance    0.19
# color        red
# estimate       0
# Name: 20, dtype: object {'trail': 'rt', 'distance': 0.19, 'color': 'red', 'estimate': 0}
# trail         rt
# distance    0.18
# color        red
# estimate       0
# Name: 21, dtype: object {'trail': 'rt', 'distance': 0.18, 'color': 'red', 'estimate': 0}
# trail         rh
# distance    0.24
# color        red
# estimate       0
# Name: 22, dtype: object {'trail': 'rh', 'distance': 0.24, 'color': 'red', 'estimate': 0}
# trail         rh
# distance    0.12
# color        red
# estimate       0
# Name: 23, dtype: object {'trail': 'rh', 'distance': 0.12, 'color': 'red', 'estimate': 0}
# trail         rh
# distance    0.06
# color        red
# estimate       0
# Name: 24, dtype: object {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# trail         rh
# distance    0.07
# color        red
# estimate       1
# Name: 25, dtype: object {'trail': 'rh', 'distance': 0.07, 'color': 'red', 'estimate': 1}
# trail         rh
# distance    0.04
# color        red
# estimate       1
# Name: 26, dtype: object {'trail': 'rh', 'distance': 0.04, 'color': 'red', 'estimate': 1}
# trail         rh
# distance    0.09
# color        red
# estimate       0
# Name: 27, dtype: object {'trail': 'rh', 'distance': 0.09, 'color': 'red', 'estimate': 0}
# trail         rh
# distance    0.06
# color        red
# estimate       0
# Name: 28, dtype: object {'trail': 'rh', 'distance': 0.06, 'color': 'red', 'estimate': 0}
# trail         rd
# distance    0.14
# color        red
# estimate       0
# Name: 29, dtype: object {'trail': 'rd', 'distance': 0.14, 'color': 'red', 'estimate': 0}
# trail         rd
# distance    0.06
# color        red
# estimate       1
# Name: 30, dtype: object {'trail': 'rd', 'distance': 0.06, 'color': 'red', 'estimate': 1}
# trail         rd
# distance    0.13
# color        red
# estimate       0
# Name: 31, dtype: object {'trail': 'rd', 'distance': 0.13, 'color': 'red', 'estimate': 0}
# trail            v
# distance      0.13
# color       violet
# estimate         0
# Name: 32, dtype: object {'trail': 'v', 'distance': 0.13, 'color': 'violet', 'estimate': 0}
# trail            v
# distance       0.3
# color       violet
# estimate         0
# Name: 33, dtype: object {'trail': 'v', 'distance': 0.3, 'color': 'violet', 'estimate': 0}
# trail            v
# distance      0.38
# color       violet
# estimate         0
# Name: 34, dtype: object {'trail': 'v', 'distance': 0.38, 'color': 'violet', 'estimate': 0}
# trail            v
# distance      0.44
# color       violet
# estimate         0
# Name: 35, dtype: object {'trail': 'v', 'distance': 0.44, 'color': 'violet', 'estimate': 0}
# trail            v
# distance       0.5
# color       violet
# estimate         0
# Name: 36, dtype: object {'trail': 'v', 'distance': 0.5, 'color': 'violet', 'estimate': 0}
# trail            v
# distance      0.27
# color       violet
# estimate         0
# Name: 37, dtype: object {'trail': 'v', 'distance': 0.27, 'color': 'violet', 'estimate': 0}
# trail            v
# distance      0.52
# color       violet
# estimate         0
# Name: 38, dtype: object {'trail': 'v', 'distance': 0.52, 'color': 'violet', 'estimate': 0}
# trail            v
# distance      0.54
# color       violet
# estimate         0
# Name: 39, dtype: object {'trail': 'v', 'distance': 0.54, 'color': 'violet', 'estimate': 0}
# trail          b
# distance     0.1
# color       blue
# estimate       0
# Name: 40, dtype: object {'trail': 'b', 'distance': 0.1, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.32
# color       blue
# estimate       0
# Name: 41, dtype: object {'trail': 'b', 'distance': 0.32, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.04
# color       blue
# estimate       1
# Name: 42, dtype: object {'trail': 'b', 'distance': 0.04, 'color': 'blue', 'estimate': 1}
# trail          b
# distance    0.16
# color       blue
# estimate       0
# Name: 43, dtype: object {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}
# trail        hack
# distance      0.0
# color       black
# estimate        0
# Name: 44, dtype: object {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# trail        hack
# distance      0.0
# color       black
# estimate        0
# Name: 45, dtype: object {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# trail          b
# distance    0.53
# color       blue
# estimate       0
# Name: 46, dtype: object {'trail': 'b', 'distance': 0.53, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.06
# color       blue
# estimate       0
# Name: 47, dtype: object {'trail': 'b', 'distance': 0.06, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.18
# color       blue
# estimate       0
# Name: 48, dtype: object {'trail': 'b', 'distance': 0.18, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.14
# color       blue
# estimate       0
# Name: 49, dtype: object {'trail': 'b', 'distance': 0.14, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.03
# color       blue
# estimate       1
# Name: 50, dtype: object {'trail': 'b', 'distance': 0.03, 'color': 'blue', 'estimate': 1}
# trail          b
# distance    0.15
# color       blue
# estimate       0
# Name: 51, dtype: object {'trail': 'b', 'distance': 0.15, 'color': 'blue', 'estimate': 0}
# trail          b
# distance     0.4
# color       blue
# estimate       0
# Name: 52, dtype: object {'trail': 'b', 'distance': 0.4, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.41
# color       blue
# estimate       0
# Name: 53, dtype: object {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.43
# color       blue
# estimate       0
# Name: 54, dtype: object {'trail': 'b', 'distance': 0.43, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.07
# color       blue
# estimate       0
# Name: 55, dtype: object {'trail': 'b', 'distance': 0.07, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.16
# color       blue
# estimate       0
# Name: 56, dtype: object {'trail': 'b', 'distance': 0.16, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.41
# color       blue
# estimate       0
# Name: 57, dtype: object {'trail': 'b', 'distance': 0.41, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    0.05
# color       blue
# estimate       1
# Name: 58, dtype: object {'trail': 'b', 'distance': 0.05, 'color': 'blue', 'estimate': 1}
# trail          b
# distance    0.08
# color       blue
# estimate       0
# Name: 59, dtype: object {'trail': 'b', 'distance': 0.08, 'color': 'blue', 'estimate': 0}
# trail          b
# distance    1.32
# color       blue
# estimate       0
# Name: 60, dtype: object {'trail': 'b', 'distance': 1.32, 'color': 'blue', 'estimate': 0}
# trail          w
# distance    0.38
# color       gray
# estimate       0
# Name: 61, dtype: object {'trail': 'w', 'distance': 0.38, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.24
# color       gray
# estimate       0
# Name: 62, dtype: object {'trail': 'w', 'distance': 0.24, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.09
# color       gray
# estimate       0
# Name: 63, dtype: object {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.18
# color       gray
# estimate       0
# Name: 64, dtype: object {'trail': 'w', 'distance': 0.18, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.09
# color       gray
# estimate       0
# Name: 65, dtype: object {'trail': 'w', 'distance': 0.09, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.33
# color       gray
# estimate       0
# Name: 66, dtype: object {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.33
# color       gray
# estimate       0
# Name: 67, dtype: object {'trail': 'w', 'distance': 0.33, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.23
# color       gray
# estimate       0
# Name: 68, dtype: object {'trail': 'w', 'distance': 0.23, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.26
# color       gray
# estimate       0
# Name: 69, dtype: object {'trail': 'w', 'distance': 0.26, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.06
# color       gray
# estimate       1
# Name: 70, dtype: object {'trail': 'w', 'distance': 0.06, 'color': 'gray', 'estimate': 1}
# trail          w
# distance    0.42
# color       gray
# estimate       0
# Name: 71, dtype: object {'trail': 'w', 'distance': 0.42, 'color': 'gray', 'estimate': 0}
# trail          w
# distance    0.12
# color       gray
# estimate       0
# Name: 72, dtype: object {'trail': 'w', 'distance': 0.12, 'color': 'gray', 'estimate': 0}
# trail           g
# distance     0.31
# color       green
# estimate        0
# Name: 73, dtype: object {'trail': 'g', 'distance': 0.31, 'color': 'green', 'estimate': 0}
# trail           g
# distance     0.26
# color       green
# estimate        0
# Name: 74, dtype: object {'trail': 'g', 'distance': 0.26, 'color': 'green', 'estimate': 0}
# trail           g
# distance     0.37
# color       green
# estimate        0
# Name: 75, dtype: object {'trail': 'g', 'distance': 0.37, 'color': 'green', 'estimate': 0}
# trail           g
# distance     0.45
# color       green
# estimate        0
# Name: 76, dtype: object {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}
# trail           g
# distance     0.05
# color       green
# estimate        1
# Name: 77, dtype: object {'trail': 'g', 'distance': 0.05, 'color': 'green', 'estimate': 1}
# trail           g
# distance     0.45
# color       green
# estimate        0
# Name: 78, dtype: object {'trail': 'g', 'distance': 0.45, 'color': 'green', 'estimate': 0}
# trail           g
# distance     0.14
# color       green
# estimate        0
# Name: 79, dtype: object {'trail': 'g', 'distance': 0.14, 'color': 'green', 'estimate': 0}
# trail            o
# distance      0.32
# color       orange
# estimate         0
# Name: 80, dtype: object {'trail': 'o', 'distance': 0.32, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.08
# color       orange
# estimate         1
# Name: 81, dtype: object {'trail': 'o', 'distance': 0.08, 'color': 'orange', 'estimate': 1}
# trail            o
# distance      0.27
# color       orange
# estimate         0
# Name: 82, dtype: object {'trail': 'o', 'distance': 0.27, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.13
# color       orange
# estimate         0
# Name: 83, dtype: object {'trail': 'o', 'distance': 0.13, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.24
# color       orange
# estimate         0
# Name: 84, dtype: object {'trail': 'o', 'distance': 0.24, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.58
# color       orange
# estimate         0
# Name: 85, dtype: object {'trail': 'o', 'distance': 0.58, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.11
# color       orange
# estimate         0
# Name: 86, dtype: object {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.15
# color       orange
# estimate         0
# Name: 87, dtype: object {'trail': 'o', 'distance': 0.15, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.33
# color       orange
# estimate         0
# Name: 88, dtype: object {'trail': 'o', 'distance': 0.33, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.06
# color       orange
# estimate         0
# Name: 89, dtype: object {'trail': 'o', 'distance': 0.06, 'color': 'orange', 'estimate': 0}
# trail            o
# distance      0.11
# color       orange
# estimate         0
# Name: 90, dtype: object {'trail': 'o', 'distance': 0.11, 'color': 'orange', 'estimate': 0}
# trail            y
# distance      0.26
# color       yellow
# estimate         0
# Name: 91, dtype: object {'trail': 'y', 'distance': 0.26, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.32
# color       yellow
# estimate         0
# Name: 92, dtype: object {'trail': 'y', 'distance': 0.32, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.31
# color       yellow
# estimate         0
# Name: 93, dtype: object {'trail': 'y', 'distance': 0.31, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.18
# color       yellow
# estimate         0
# Name: 94, dtype: object {'trail': 'y', 'distance': 0.18, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.53
# color       yellow
# estimate         0
# Name: 95, dtype: object {'trail': 'y', 'distance': 0.53, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.16
# color       yellow
# estimate         0
# Name: 96, dtype: object {'trail': 'y', 'distance': 0.16, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.28
# color       yellow
# estimate         0
# Name: 97, dtype: object {'trail': 'y', 'distance': 0.28, 'color': 'yellow', 'estimate': 0}
# trail            y
# distance      0.14
# color       yellow
# estimate         0
# Name: 98, dtype: object {'trail': 'y', 'distance': 0.14, 'color': 'yellow', 'estimate': 0}
# trail          tt
# distance     0.16
# color       black
# estimate        0
# Name: 99, dtype: object {'trail': 'tt', 'distance': 0.16, 'color': 'black', 'estimate': 0}
# trail          tt
# distance      0.2
# color       black
# estimate        0
# Name: 100, dtype: object {'trail': 'tt', 'distance': 0.2, 'color': 'black', 'estimate': 0}
# trail          tt
# distance     0.15
# color       black
# estimate        1
# Name: 101, dtype: object {'trail': 'tt', 'distance': 0.15, 'color': 'black', 'estimate': 1}
# trail          tt
# distance     0.11
# color       black
# estimate        1
# Name: 102, dtype: object {'trail': 'tt', 'distance': 0.11, 'color': 'black', 'estimate': 1}
# trail          tt
# distance     0.13
# color       black
# estimate        0
# Name: 103, dtype: object {'trail': 'tt', 'distance': 0.13, 'color': 'black', 'estimate': 0}
# trail          tt
# distance     0.06
# color       black
# estimate        1
# Name: 104, dtype: object {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}
# trail          tt
# distance     0.08
# color       black
# estimate        0
# Name: 105, dtype: object {'trail': 'tt', 'distance': 0.08, 'color': 'black', 'estimate': 0}
# trail          tt
# distance     0.03
# color       black
# estimate        1
# Name: 106, dtype: object {'trail': 'tt', 'distance': 0.03, 'color': 'black', 'estimate': 1}
# trail          tt
# distance     0.36
# color       black
# estimate        0
# Name: 107, dtype: object {'trail': 'tt', 'distance': 0.36, 'color': 'black', 'estimate': 0}
# trail          tt
# distance     0.06
# color       black
# estimate        1
# Name: 108, dtype: object {'trail': 'tt', 'distance': 0.06, 'color': 'black', 'estimate': 1}
# trail          tt
# distance     0.18
# color       black
# estimate        0
# Name: 109, dtype: object {'trail': 'tt', 'distance': 0.18, 'color': 'black', 'estimate': 0}
# trail        hack
# distance      0.0
# color       black
# estimate        0
# Name: 110, dtype: object {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# trail        hack
# distance      0.0
# color       black
# estimate        0
# Name: 111, dtype: object {'trail': 'hack', 'distance': 0.0, 'color': 'black', 'estimate': 0}
# trail            nature
# distance           0.11
# color       forestgreen
# estimate              0
# Name: 112, dtype: object {'trail': 'nature', 'distance': 0.11, 'color': 'forestgreen', 'estimate': 0}
# trail            nature
# distance           0.35
# color       forestgreen
# estimate              0
# Name: 113, dtype: object {'trail': 'nature', 'distance': 0.35, 'color': 'forestgreen', 'estimate': 0}
# trail              bw
# distance         0.19
# color       lightblue
# estimate            0
# Name: 114, dtype: object {'trail': 'bw', 'distance': 0.19, 'color': 'lightblue', 'estimate': 0}
# trail               gy1
# distance           0.15
# color       yellowgreen
# estimate              0
# Name: 115, dtype: object {'trail': 'gy1', 'distance': 0.15, 'color': 'yellowgreen', 'estimate': 0}
# trail               gy1
# distance           0.16
# color       yellowgreen
# estimate              0
# Name: 116, dtype: object {'trail': 'gy1', 'distance': 0.16, 'color': 'yellowgreen', 'estimate': 0}
# trail               gy1
# distance           0.14
# color       yellowgreen
# estimate              0
# Name: 117, dtype: object {'trail': 'gy1', 'distance': 0.14, 'color': 'yellowgreen', 'estimate': 0}
# trail           bv
# distance      0.08
# color       purple
# estimate         0
# Name: 118, dtype: object {'trail': 'bv', 'distance': 0.08, 'color': 'purple', 'estimate': 0}
# trail               gy2
# distance           0.05
# color       yellowgreen
# estimate              0
# Name: 119, dtype: object {'trail': 'gy2', 'distance': 0.05, 'color': 'yellowgreen', 'estimate': 0}
# trail               gy2
# distance           0.03
# color       yellowgreen
# estimate              1
# Name: 120, dtype: object {'trail': 'gy2', 'distance': 0.03, 'color': 'yellowgreen', 'estimate': 1}
# trail               gy2
# distance           0.07
# color       yellowgreen
# estimate              0
# Name: 121, dtype: object {'trail': 'gy2', 'distance': 0.07, 'color': 'yellowgreen', 'estimate': 0}
# trail               gy2
# distance           0.12
# color       yellowgreen
# estimate              0
# Name: 122, dtype: object {'trail': 'gy2', 'distance': 0.12, 'color': 'yellowgreen', 'estimate': 0}

# %%
g

# %%
# g.edges

# %%
# Add node attributes
for i, nlrow in nodelist.iterrows():
    g.nodes[nlrow['id']] = nlrow[1:].to_dict()
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 # Add node attributes
#       2 for i, nlrow in nodelist.iterrows():
# ----> 3     g.nodes[nlrow['id']] = nlrow[1:].to_dict()
#
# TypeError: 'NodeView' object does not support item assignment

# %%
# g.edges(data=True)#[0:5]

# %%
g.nodes(data=True)
# Out:
# NodeDataView({'rs_end_north': {}, 'v_rs': {}, 'b_rs': {}, 'g_rs': {}, 'w_rs': {}, 'o_rs': {}, 'y_rs': {}, 'rs_end_south': {}, 'rc_end_north': {}, 'v_rc': {}, 'b_rc': {}, 'g_rc': {}, 'o_rc': {}, 'w_rc': {}, 'y_rc': {}, 'rc_end_south': {}, 'rt_end_north': {}, 'v_rt': {}, 'tt_rt': {}, 'b_rt': {}, 'g_rt': {}, 'o_rt': {}, 'w_rt': {}, 'y_rt': {}, 'rt_end_south': {}, 'rh_end_north': {}, 'v_rh': {}, 'b_rh': {}, 'rh_end_tt_1': {}, 'rh_end_tt_2': {}, 'o_rh': {}, 'rh_end_tt_3': {}, 'rh_end_tt_4': {}, 'y_rh': {}, 'rh_end_south': {}, 'rd_end_north': {}, 'v_rd': {}, 'b_rd': {}, 'rd_end_south': {}, 'v_end_west': {}, 'b_v': {}, 'v_bv': {}, 'v_end_east': {}, 'bstub_w': {}, 'b_end_west': {}, 'rd_end_south_dupe': {}, 'b_rd_dupe': {}, 'b_tt_1': {}, 'b_bw': {}, 'b_tt_2': {}, 'b_tt_3': {}, 'b_bv': {}, 'b_g': {}, 'b_w': {}, 'b_gy2': {}, 'b_o': {}, 'b_y': {}, 'b_end_east': {}, 'w_tt': {}, 'w_bw': {}, 'g_w': {}, 'o_w_1': {}, 'w_gy1': {}, 'o_w_2': {}, 'w_gy2': {}, 'park_east': {}, 'g_gy1': {}, 'g_gy2': {}, 'o_y_tt_end_west': {}, 'o_tt': {}, 'o_gy1': {}, 'o_gy2': {}, 'y_gy1': {}, 'y_gy2': {}, 'nature_end_west': {}, 'b_tt_2_dupe': {}, 'b_tt_3_dupe': {}})
